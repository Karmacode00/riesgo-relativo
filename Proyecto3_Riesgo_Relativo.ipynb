# %% [markdown]
# # Análisis exploratorio

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

df = pd.read_csv('/content/drive/MyDrive/bq-results-20240108-153108-1704728018731/proyecto_3_clean.csv')
# df.head()
# df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36000 entries, 0 to 35999
# Data columns (total 14 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   user_id                                       36000 non-null  int64
#  1   default_flag                                  36000 non-null  int64
#  2   age                                           36000 non-null  int64
#  3   sex                                           36000 non-null  int64
#  4   last_month_salary                             28801 non-null  float64
#  5   number_dependents                             36000 non-null  int64
#  6   more_90_days_overdue                          36000 non-null  int64
#  7   using_lines_not_secured_personal_assets       36000 non-null  float64
#  8   number_times_delayed_payment_loan_30_59_days  36000 non-null  int64
# ...

# %%
#Plot age
plt.figure(figsize=(12, 2))
sbn.boxplot(x='age', data=df)
plt.title('Boxplot age')
plt.show()

#Histograma
plt.figure(figsize=(12, 4))
plt.hist(df['age'], bins=30, color='skyblue', edgecolor='black'), plt.title('Histograma age', fontsize=16)
plt.xlabel('age', fontsize=14)
plt.ylabel('frequency', fontsize=14)
plt.show()

# %% [markdown]
# # Imputación

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
dfr = pd.DataFrame(scaler.fit_transform(df), columns = df.columns)
dfr.head()

from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
dfr = pd.DataFrame(imputer.fit_transform(df), columns = df.columns)
dfr.head()
dfr.info()
dfr.to_csv('/content/drive/MyDrive/bq-results-20240108-153108-1704728018731/out.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36000 entries, 0 to 35999
# Data columns (total 14 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   user_id                                       36000 non-null  float64
#  1   default_flag                                  36000 non-null  float64
#  2   age                                           36000 non-null  float64
#  3   sex                                           36000 non-null  float64
#  4   last_month_salary                             36000 non-null  float64
#  5   number_dependents                             36000 non-null  float64
#  6   more_90_days_overdue                          36000 non-null  float64
#  7   using_lines_not_secured_personal_assets       36000 non-null  float64
#  8   number_times_delayed_payment_loan_30_59_days  36000 non-null  float64
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

df = pd.read_csv('/content/drive/MyDrive/bq-results-20240110-140822-1704895711952/complete_table.csv')
# df.head()
# df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36000 entries, 0 to 35999
# Data columns (total 14 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   user_id                                       36000 non-null  int64
#  1   default_flag                                  36000 non-null  int64
#  2   age                                           36000 non-null  int64
#  3   sex                                           36000 non-null  int64
#  4   last_month_salary                             36000 non-null  float64
#  5   number_dependents                             36000 non-null  int64
#  6   more_90_days_overdue                          36000 non-null  int64
#  7   using_lines_not_secured_personal_assets       36000 non-null  float64
#  8   number_times_delayed_payment_loan_30_59_days  36000 non-null  int64
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

df = pd.read_csv('/content/drive/MyDrive/bq-results-20240111-141107-1704982277461/proyecto3_incomplete_table.csv')
df.info()

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
dfr = pd.DataFrame(scaler.fit_transform(df), columns = df.columns)
# dfr.head()

from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
dfr = pd.DataFrame(imputer.fit_transform(df), columns = df.columns)
# dfr.head()
dfr.info()
dfr.to_csv('/content/drive/MyDrive/bq-results-20240111-141107-1704982277461/proyecto3_imputed_table.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36000 entries, 0 to 35999
# Data columns (total 14 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   user_id                                       36000 non-null  int64
#  1   default_flag                                  36000 non-null  int64
#  2   age                                           36000 non-null  int64
#  3   sex                                           36000 non-null  int64
#  4   last_month_salary                             28801 non-null  float64
#  5   number_dependents                             35057 non-null  float64
#  6   more_90_days_overdue                          36000 non-null  int64
#  7   using_lines_not_secured_personal_assets       36000 non-null  float64
#  8   number_times_delayed_payment_loan_30_59_days  36000 non-null  int64
# ...

# %% [markdown]
# # Predicción con Score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn import metrics

df = pd.read_csv('/content/drive/MyDrive/bq-results-20240118-152301-1705591769362/bq-results-20240118-152301-1705591769362.csv')


# Generar datos de ejemplo de etiquetas reales y predichas
actual = df['default_flag']
predicted = df['default_flag_prediction']

# Crear la matriz de confusión utilizando sklearn
confusion_matrix = metrics.confusion_matrix(actual, predicted)

# Crear la visualización de la matriz de confusión
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

# Graficar la matriz de confusión
cm_display.plot()
plt.show()

#Exactitud
Accuracy = metrics.accuracy_score(actual, predicted)

#Precisión
Precision = metrics.precision_score(actual, predicted)

#Sensibilidad/recall
Sensitivity_recall = metrics.recall_score(actual, predicted)

#Especificidad
Specificity = metrics.recall_score(actual, predicted, pos_label=0)

#F Score
F1_score = metrics.f1_score(actual, predicted)

#metrics
print({"Accuracy":Accuracy,"Precision":Precision,"Sensitivity_recall":Sensitivity_recall,"Specificity":Specificity,"F1_score":F1_score})
# Out:
# {'Accuracy': 0.9497777777777778, 'Precision': 0.2574385510996119, 'Sensitivity_recall': 0.8740849194729137, 'Specificity': 0.951241611688422, 'F1_score': 0.3977348434377082}

# %%
df.head()
df[['total_score', 'default_flag']].plot.scatter(x='total_score', y='default_flag')

# %% [markdown]
# # Regresión logística con variables dummy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn import metrics

df = pd.read_csv('/content/drive/MyDrive/bq-results-20240118-152301-1705591769362/bq-results-20240118-152301-1705591769362.csv')

# %%
df.drop(['age',
 'sex',
 'last_month_salary',
 'number_dependents',
 'more_90_days_overdue',
 'using_lines_not_secured_personal_assets',
 'number_times_delayed_payment_loan_30_59_days',
 'number_times_delayed_payment_loan_60_89_days',
 'debt_ratio',
 'real_estate_loan',
 'other_loan',
 'total_loan',
 'quartile_age',
 'quartile_total_loan',
 'quartile_salary',
 'overdue',
 'quartile_debt_ratio',
 'quartile_lines',
 'score_age',
 'score_total_loan',
 'score_salary',
 'score_overdue',
 'score_debt_ratio',
 'score_lines',
 'total_score',
 'default_flag_prediction'],axis=1,inplace=True)



#predictors = [var for var in dfr if var not in ['user_id', 'default_flag']]

#dfr.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36000 entries, 0 to 35999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           36000 non-null  int64
#  1   default_flag      36000 non-null  int64
#  2   dummy_age         36000 non-null  int64
#  3   dummy_total_loan  36000 non-null  int64
#  4   dummy_salary      36000 non-null  int64
#  5   dummy_overdue     36000 non-null  int64
#  6   dummy_debt_ratio  36000 non-null  int64
#  7   dummy_lines       36000 non-null  int64
# dtypes: int64(8)
# memory usage: 2.2 MB

# %%
predictors = [var for var in df if var not in ['user_id', 'default_flag']]

predictors
# Out:
# ['dummy_age',
#  'dummy_total_loan',
#  'dummy_salary',
#  'dummy_overdue',
#  'dummy_debt_ratio',
#  'dummy_lines']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df,
                                                    df['default_flag'], test_size=0.20, stratify=df['default_flag']
                                                    )

print({"x_train shape": X_train.shape})
print({"x_test shape": X_test.shape})
print({"y_traim mean": y_train.mean()})
print({"y_test mean": y_test.mean()})
# Out:
# {'x_train shape': (28800, 8)}
# {'x_test shape': (7200, 8)}
# {'y_traim mean': 0.018958333333333334}
# {'y_test mean': 0.01902777777777778}

# %%
from sklearn.linear_model import LogisticRegression

logmodel = LogisticRegression() #instanciar
logmodel.fit(X_train[predictors],y_train) #entrenar
# Out:
# LogisticRegression()

# %%
predictions = logmodel.predict(X_test[predictors]) # predecir
X_test.head()
# Out:
#        user_id  default_flag  dummy_age  dummy_total_loan  dummy_salary  \
# 15263     1870             0          0                 0             0
# 21793     5401             0          1                 0             0
# 722      33208             0          0                 0             0
# 1340      4176             0          0                 1             0
# 512      22933             0          0                 0             1
#
#        dummy_overdue  dummy_debt_ratio  dummy_lines
# 15263              0                 0            0
# 21793              0                 0            0
# 722                0                 1            0
# 1340               0                 0            1
# 512                0                 0            0

# %%
X_test['y_pred'] = predictions
X_test.head()
# Out:
#        user_id  default_flag  dummy_age  dummy_total_loan  dummy_salary  \
# 15263     1870             0          0                 0             0
# 21793     5401             0          1                 0             0
# 722      33208             0          0                 0             0
# 1340      4176             0          0                 1             0
# 512      22933             0          0                 0             1
#
#        dummy_overdue  dummy_debt_ratio  dummy_lines  y_pred
# 15263              0                 0            0       0
# 21793              0                 0            0       0
# 722                0                 1            0       0
# 1340               0                 0            1       0
# 512                0                 0            0       0

# %% [markdown]
# # Evaluar regresión logística con variables dummy

# %%
from sklearn.metrics import classification_report,confusion_matrix

cm = confusion_matrix(y_test,predictions)

print(cm)
# Out:
# [[7041   22]
#  [ 111   26]]

# %%
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])

# Graficar la matriz de confusión
cm_display.plot()
plt.show()

# %%
print(classification_report(y_test,predictions))

#Exactitud
Accuracy = metrics.accuracy_score(y_test, predictions)

#Precisión
Precision = metrics.precision_score(y_test, predictions)

#Sensibilidad/recall
Sensitivity_recall = metrics.recall_score(y_test, predictions)

#Especificidad
Specificity = metrics.recall_score(y_test, predictions, pos_label=0)

#F Score
F1_score = metrics.f1_score(y_test, predictions)

#metrics
print({"Accuracy":Accuracy,"Precision":Precision,"Sensitivity_recall":Sensitivity_recall,"Specificity":Specificity,"F1_score":F1_score})
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      7063
#          1.0       0.02      0.01      0.01       137
#
#     accuracy                           0.97      7200
#    macro avg       0.50      0.50      0.50      7200
# weighted avg       0.96      0.97      0.97      7200
#
# {'Accuracy': 0.9745833333333334, 'Precision': 0.020833333333333332, 'Sensitivity_recall': 0.0072992700729927005, 'Specificity': 0.9933456038510547, 'F1_score': 0.01081081081081081}

# %%
logmodel_all = LogisticRegression() #instanciar
logmodel_all.fit(df[predictors],df['default_flag']) #entrenar

print(classification_report(df['default_flag'],logmodel_all.predict(df[predictors])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     35317
#            1       0.52      0.23      0.32       683
#
#     accuracy                           0.98     36000
#    macro avg       0.75      0.61      0.66     36000
# weighted avg       0.98      0.98      0.98     36000

# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline

coef = pd.Series(logmodel_all.coef_[0], index = predictors)
print(coef.sort_values())

imp_coef = pd.concat([coef.sort_values()])
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Coefficients regression")

var_impor = imp_coef.index
var_impor = list(var_impor)
# Out:
# dummy_total_loan   -0.521136
# dummy_salary        0.178087
# dummy_age           0.241665
# dummy_debt_ratio    0.540481
# dummy_lines         2.513512
# dummy_overdue       4.895678
# dtype: float64

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

logit_roc_auc = roc_auc_score(y_test, logmodel.predict(X_test[predictors]))
fpr, tpr, thresholds = roc_curve(y_test, logmodel.predict_proba(X_test[predictors])[:,1])
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %% [markdown]
# # Regresión logística con variables originales

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

train = pd.read_csv('/content/drive/MyDrive/bq-results-20240118-152301-1705591769362/bq-results-20240118-152301-1705591769362.csv')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36000 entries, 0 to 35999
# Data columns (total 34 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   user_id                                       36000 non-null  int64
#  1   default_flag                                  36000 non-null  int64
#  2   age                                           36000 non-null  int64
#  3   sex                                           36000 non-null  int64
#  4   last_month_salary                             36000 non-null  int64
#  5   number_dependents                             36000 non-null  int64
#  6   more_90_days_overdue                          36000 non-null  int64
#  7   using_lines_not_secured_personal_assets       36000 non-null  float64
#  8   number_times_delayed_payment_loan_30_59_days  36000 non-null  int64
# ...

# %%
train.drop(['dummy_age',
         'dummy_total_loan',
         'dummy_salary',
         'dummy_overdue',
         'dummy_debt_ratio',
         'dummy_lines',
 'sex',
 'number_dependents',
 'number_times_delayed_payment_loan_30_59_days',
 'number_times_delayed_payment_loan_60_89_days',
 'real_estate_loan',
 'other_loan',
 'quartile_age',
 'quartile_total_loan',
 'quartile_salary',
 'overdue',
 'quartile_debt_ratio',
 'quartile_lines',
 'score_age',
 'score_total_loan',
 'score_salary',
 'score_overdue',
 'score_debt_ratio',
 'score_lines',
 'total_score',
 'default_flag_prediction'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

train = pd.DataFrame(scaler.fit_transform(train), columns = train.columns)
train.head()
# Out:
#     user_id  default_flag       age  last_month_salary  more_90_days_overdue  \
# 0  0.000444           0.0  0.773333           0.252004                   0.0
# 1  0.004972           0.0  0.600000           0.192003                   0.0
# 2  0.009778           0.0  0.506667           0.100802                   0.0
# 3  0.011195           0.0  0.466667           0.160803                   0.0
# 4  0.011223           0.0  0.640000           0.000000                   0.0
#
#    using_lines_not_secured_personal_assets    debt_ratio  total_loan
# 0                                 0.000006  2.698664e-07    0.375000
# 1                                 0.000003  4.987145e-07    0.428571
# 2                                 0.000005  4.504885e-06    0.410714
# 3                                 0.000003  2.082428e-06    0.535714
# 4                                 0.000008  4.040052e-02    0.535714

# %%
predictors = [var for var in train if var not in ['user_id', 'default_flag']]

predictors
# Out:
# ['age',
#  'last_month_salary',
#  'more_90_days_overdue',
#  'using_lines_not_secured_personal_assets',
#  'debt_ratio',
#  'total_loan']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train,
                                                    train['default_flag'], test_size=0.20, stratify=train['default_flag']
                                                    )


print({"x_train shape": X_train.shape})
print({"x_test shape": X_test.shape})
print({"y_traim mean": y_train.mean()})
print({"y_test mean": y_test.mean()})
# Out:
# {'x_train shape': (28800, 8)}
# {'x_test shape': (7200, 8)}
# {'y_traim mean': 0.018958333333333334}
# {'y_test mean': 0.01902777777777778}

# %%
from sklearn.linear_model import LogisticRegression

logmodel = LogisticRegression() #instanciar
logmodel.fit(X_train[predictors],y_train) #entrenar
# Out:
# LogisticRegression()

# %%
predictions = logmodel.predict(X_test[predictors]) # predecir
X_test.head()
# Out:
#         user_id  default_flag       age  last_month_salary  \
# 28577  0.074641           0.0  0.560000           0.098402
# 5262   0.657935           0.0  0.053333           0.024000
# 24179  0.004639           0.0  0.466667           0.065281
# 13651  0.572405           0.0  0.786667           0.000024
# 941    0.375399           0.0  0.373333           0.055993
#
#        more_90_days_overdue  using_lines_not_secured_personal_assets  \
# 28577              0.000000                             3.444966e-05
# 5262               0.000000                             4.545454e-05
# 24179              0.010204                             4.367530e-05
# 13651              0.000000                             7.045319e-07
# 941                0.000000                             4.545454e-05
#
#          debt_ratio  total_loan
# 28577  2.956288e-06    0.196429
# 5262   2.176969e-06    0.035714
# 24179  8.104390e-07    0.160714
# 13651  1.990222e-03    0.089286
# ...

# %%
X_test['y_pred'] = predictions

# %%
X_test.head()
# Out:
#         user_id  default_flag       age  last_month_salary  \
# 28577  0.074641           0.0  0.560000           0.098402
# 5262   0.657935           0.0  0.053333           0.024000
# 24179  0.004639           0.0  0.466667           0.065281
# 13651  0.572405           0.0  0.786667           0.000024
# 941    0.375399           0.0  0.373333           0.055993
#
#        more_90_days_overdue  using_lines_not_secured_personal_assets  \
# 28577              0.000000                             3.444966e-05
# 5262               0.000000                             4.545454e-05
# 24179              0.010204                             4.367530e-05
# 13651              0.000000                             7.045319e-07
# 941                0.000000                             4.545454e-05
#
#          debt_ratio  total_loan  y_pred
# 28577  2.956288e-06    0.196429     0.0
# 5262   2.176969e-06    0.035714     0.0
# 24179  8.104390e-07    0.160714     0.0
# ...

# %% [markdown]
# # Evaluar regresión logística con variables originales

# %%
from sklearn.metrics import classification_report,confusion_matrix

cm = confusion_matrix(y_test,predictions)

print(cm)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])

# Graficar la matriz de confusión
cm_display.plot()
plt.show()
# Out:
# [[7061    2]
#  [ 124   13]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      7063
#          1.0       0.87      0.09      0.17       137
#
#     accuracy                           0.98      7200
#    macro avg       0.92      0.55      0.58      7200
# weighted avg       0.98      0.98      0.98      7200

# %%
print(classification_report(y_test,predictions))

#Exactitud
Accuracy = metrics.accuracy_score(y_test, predictions)

#Precisión
Precision = metrics.precision_score(y_test, predictions)

#Sensibilidad/recall
Sensitivity_recall = metrics.recall_score(y_test, predictions)

#Especificidad
Specificity = metrics.recall_score(y_test, predictions, pos_label=0)

#F Score
F1_score = metrics.f1_score(y_test, predictions)

#metrics
print({"Accuracy":Accuracy,"Precision":Precision,"Sensitivity_recall":Sensitivity_recall,"Specificity":Specificity,"F1_score":F1_score})
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7063
#            1       0.58      0.16      0.25       137
#
#     accuracy                           0.98      7200
#    macro avg       0.78      0.58      0.62      7200
# weighted avg       0.98      0.98      0.98      7200
#
# {'Accuracy': 0.9818055555555556, 'Precision': 0.5789473684210527, 'Sensitivity_recall': 0.16058394160583941, 'Specificity': 0.9977346736514229, 'F1_score': 0.25142857142857145}

# %%
logmodel_all = LogisticRegression() #instanciar
logmodel_all.fit(train[predictors],train['default_flag']) #entrenar

print(classification_report(train['default_flag'],logmodel_all.predict(train[predictors])))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99     35317
#          1.0       0.81      0.07      0.14       683
#
#     accuracy                           0.98     36000
#    macro avg       0.90      0.54      0.56     36000
# weighted avg       0.98      0.98      0.97     36000

# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline

coef = pd.Series(logmodel_all.coef_[0], index = predictors)
print(coef.sort_values())

imp_coef = pd.concat([coef.sort_values()])
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Coefficients regression")

var_impor = imp_coef.index
var_impor = list(var_impor)
# Out:
# age                                       -2.277892
# last_month_salary                         -2.198304
# total_loan                                -2.076896
# debt_ratio                                -0.238496
# using_lines_not_secured_personal_assets   -0.130046
# more_90_days_overdue                       6.116568
# dtype: float64

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

logit_roc_auc = roc_auc_score(y_test, logmodel.predict(X_test[predictors]))
fpr, tpr, thresholds = roc_curve(y_test, logmodel.predict_proba(X_test[predictors])[:,1])
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
